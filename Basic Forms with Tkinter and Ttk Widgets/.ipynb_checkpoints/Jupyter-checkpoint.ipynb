# %%
def fibs(amount):
    list = [0, 1]
    for i in range(amount):
        list.append(list[0]+list[1])
        print(list[0] + list[1])
        list.pop(0)
fibs(34)

# %%
import tkinter as tk
from tkinter import ttk
